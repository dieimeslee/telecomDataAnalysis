# %% [markdown]
# Empresa de telecom com diversos serviços, os principais são internet e telefone.
# Analisando histórico de clienter está em queda de mais de 26%
# O que precisa ser feito?
# Base de dados do Kaggle: https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers

# %%
#1 importar base de dados
#pandas, numpy, openpyxl

#2 visualizar a base de dados
# Entender as informações
# Descobrir inconsistências(coisas inúteis, tipo correto)
# Tratamento de dados
# Análise inicial(superficial) dos dados
# Descobrir motivos do cancelamento (Churn)

# %%
import pandas as pd

table = pd.read_csv('telecom_users.csv')
table = table.drop('Unnamed: 0', axis=1)
display(table)

#incorrect dtype
table['TotalGasto'] = pd.to_numeric(table['TotalGasto'], errors='coerce')

#colluns with all information empty are useless
table = table.dropna(how='all', axis=1)
#lines with some empty information will drop
table = table.dropna(how='any', axis=0)

print(table.info())
# Out:
#        IDCliente     Genero  Aposentado Casado Dependentes  MesesComoCliente  \
# 0     7010-BRBUU  Masculino           0    Sim         Sim                72
# 1     9688-YGXVR   Feminino           0    Nao         Nao                44
# 2     9286-DOJGF   Feminino           1    Sim         Nao                38
# 3     6994-KERXL  Masculino           0    Nao         Nao                 4
# 4     2181-UAESM  Masculino           0    Nao         Nao                 2
# ...          ...        ...         ...    ...         ...               ...
# 5981  0684-AOSIH  Masculino           0    Sim         Nao                 1
# 5982  5982-PSMKW   Feminino           0    Sim         Sim                23
# 5983  8044-BGWPI  Masculino           0    Sim         Sim                12
# 5984  7450-NWRTR  Masculino           1    Nao         Nao                12
# 5985  4795-UXVCJ  Masculino           0    Nao         Nao                26
#
# ...
